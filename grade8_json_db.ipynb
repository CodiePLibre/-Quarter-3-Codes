# %% [markdown]
# <a href="https://colab.research.google.com/github/CodiePLibre/-Quarter-3-Codes/blob/main/grade8_json_db.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install firebase-admin

# %%
import json
# Open the JSON file
with open("/students.JSON") as f:
  students = json.load(f)
# Display the JSON content
print(students)
# Out:
# {'students': [{'id': 1001, 'name': 'Czarina', 'grades': {'Math': 92, 'CS': 88}}, {'id': 1002, 'name': 'Miguel', 'grades': {'Math': 85, 'CS': 90}}]}

# %%
import firebase_admin
from firebase_admin import credentials, db
# Load the private key
cred = credentials.Certificate("/content/firebase_key.json")
# Initialize the app with your database URL
firebase_admin.initialize_app(cred, {
 "databaseURL": "https://grade8-json-db-f8716-default-rtdb.asia-southeast1.firebasedatabase.app/"
})
print("Firebase connected successfully!")
# Out:
# Firebase connected successfully!

# %%
import json
with open("/content/students.json", "r") as file:
 data = json.load(file)
print("JSON file loaded")
ref = db.reference("students")
for student in data["students"]:
 ref.child(str(student["id"])).set(student)
print("Data uploaded successfully!")
# Out:
# JSON file loaded
# Data uploaded successfully!

# %%
students_ref = db.reference("students")
students_data = students_ref.get()
print(students_data)
# Out:
# {'1001': {'grades': {'CS': 88, 'Math': 92}, 'id': 1001, 'name': 'Czarina'}, '1002': {'grades': {'CS': 90, 'Math': 85}, 'id': 1002, 'name': 'Miguel'}}

# %%
for student_id, info in students_data.items():
 print(info["name"])
# Out:
# Czarina
# Miguel

# %%
for student_id, info in students_data.items():
 print(info["name"], info["grades"])
# Out:
# Czarina {'CS': 88, 'Math': 92}
# Miguel {'CS': 90, 'Math': 85}

# %%
# Fetch data from Firebase
students_data = ref.get() # returns a dictionary with keys "0", "1", ...
# Loop through each student
for key, student in students_data.items():
 name = student["name"]
 grades = student["grades"].values()
 avg = sum(grades) / len(grades)
 print(f"Student: {name}")
 print(f"Grades: {student['grades']}")
 print(f"Average: {avg:.2f}\n")
# Out:
# Student: Czarina
# Grades: {'CS': 88, 'Math': 92}
# Average: 90.00
#
# Student: Miguel
# Grades: {'CS': 90, 'Math': 85}
# Average: 87.50

# %%
import requests
import json
url = "https://raw.githubusercontent.com/CodiePLibre/-Quarter-3-Codes/refs/heads/main/students.JSON"
response = requests.get(url)
students = response.json()
print(students)
#make sure the url is the raw file from the githu
# Out:
# {'students': [{'id': 1001, 'name': 'Czarina', 'grades': {'Math': 92, 'CS': 88}}, {'id': 1002, 'name': 'Miguel', 'grades': {'Math': 85, 'CS': 90}}]}

# %%
import requests
import json
import firebase_admin
from firebase_admin import credentials, db
# Step 1: Download the key from GitHub
url = "https://raw.githubusercontent.com/CodiePLibre/-Quarter-3-Codes/refs/heads/main/firebase_key.json"
response = requests.get(url)
# Step 2: Save it locally in Colab
with open("firebase_key.json", "wb") as f:
  f.write(response.content)
  # Step 3: Initialize Firebase
  # Check if the default Firebase app is already initialized
if not firebase_admin._apps:
  cred = credentials.Certificate("firebase_key.json")
  firebase_admin.initialize_app(cred, {
  'databaseURL': 'https://grade8-json-db-f8716-default-rtdb.asia-southeast1.firebasedatabase.app/'
  })
  print("Connected to Firebase!")
else:
  print("Firebase app already initialized.")
  #make sure the url is the raw file from the github
# Out:
# Firebase app already initialized.
